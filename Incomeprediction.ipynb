# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhijeet088/ML/blob/main/Incomeprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas matplotlib seaborn scikit-learn numpy

# %%
import pandas as pd
