# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhijeet088/ML/blob/main/Softmax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hellow World")
# Out:
# hellow World

# %%
print ((()))
